# %% [markdown]
# ### 백터 공간에서 단어들이 어떻게 표현되는지 실습해 봅시다.

# %% [markdown]
# - https://vectors.nlpl.eu/explore/embeddings/en/calculator/#
# - 왼쪽에 Korea_PROPN, Busan_PROPN 입력하고 오른쪽에 Japan_PROPN을 입력하면 ??

# %% [markdown]
# - https://vectors.nlpl.eu/explore/embeddings/en/associates/#
# - mother_NOUN와 관계된 단어는

# %% [markdown]
# - https://vectors.nlpl.eu/explore/embeddings/en/visual/
# - 단어들 사이의 관계는
# - clean_ADJ,Paris_PROPN,France_PROPN,computer_NOUN,new_ADJ,tank_NOUN,Russia_PROPN,car_NOUN,dirty_ADJ,mouse_NOUN,Britain_PROPN,transport_NOUN,Moscow_ADV,London_PROPN
